# %% [markdown]
# # Graduation Rates vs SAT (Public vs Private)
#
# This notebook reproduces the core analysis:
# - Scatter plots of graduation rate vs SAT
# - Correlations by sector
# - Separate least-squares regressions (public vs private)
# - Prediction for Truman at SAT ≈ 1190
# - (Bonus) Single model with an interaction term (ANCOVA-style)
# - Regression diagnostics (residuals, Q-Q, Cook's distance)
# - Interactive plot (Plotly)
#
# Dataset: `data/GradRates.xlsx` (cleaned version: `data/grad_rates_clean.csv`)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from scipy import stats
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import OLSInfluence
import plotly.graph_objects as go

df = pd.read_csv("/content/grad_rates_clean.csv")
df.head(), df.shape
# Out:
# (                           college_name state  sector  graduation_rate  \
#  0               Angelo State University    TX  Public             34.0
#  1  California State Univ. at Long Beach    CA  Public             48.0
#  2           College of William and Mary    VA  Public             93.0
#  3                 CUNY-Brooklyn College    NY  Public             43.0
#  4              East Carolina University    NC  Public             58.0
#
#     sat_total  sat_imputed
#  0      950.0            0
#  1      838.0            0
#  2     1240.0            0
#  3      916.0            0
#  4      921.0            0  ,
#  (47, 6))

# %%
df['sector'].value_counts()
# Out:
# sector
# Private    27
# Public     20
# Name: count, dtype: int64

# %% [markdown]
# ## 1. Correlations

# %%
def corr_test(sub):
    r, p = stats.pearsonr(sub['sat_total'], sub['graduation_rate'])
    return r, p

r_pub, p_pub = corr_test(df[df['sector'] == 'Public'])
r_pri, p_pri = corr_test(df[df['sector'] == 'Private'])

print(f"Public:  r = {r_pub:.3f}, p = {p_pub:.6f}")
print(f"Private: r = {r_pri:.3f}, p = {p_pri:.6f}")
# Out:
# Public:  r = 0.701, p = 0.000574
# Private: r = 0.572, p = 0.001805

# %% [markdown]
# ## 2. Separate OLS Regressions

# %%
def linreg(sub):
    x = sub['sat_total'].astype(float)
    y = sub['graduation_rate'].astype(float)
    slope, intercept, r, p, se = stats.linregress(x, y)
    return slope, intercept, r, p, se

pub = df[df['sector'] == 'Public']
pri = df[df['sector'] == 'Private']

pub_slope, pub_int, pub_r, pub_p, pub_se = linreg(pub)
pri_slope, pri_int, pri_r, pri_p, pri_se = linreg(pri)

print(f"Public:  grad_rate = {pub_int:.3f} + {pub_slope:.6f} * sat_total  (r={pub_r:.3f}, p={pub_p:.6f})")
print(f"Private: grad_rate = {pri_int:.3f} + {pri_slope:.6f} * sat_total  (r={pri_r:.3f}, p={pri_p:.6f})")
# Out:
# Public:  grad_rate = -51.385 + 0.103957 * sat_total  (r=0.701, p=0.000574)
# Private: grad_rate = 8.939 + 0.061701 * sat_total  (r=0.572, p=0.001805)

# %% [markdown]
# ## 3. Truman State Prediction (SAT ≈ 1190)

# %%
sat_truman = 1190
pred_truman = pub_int + pub_slope * sat_truman
actual_truman = 76.0
residual = actual_truman - pred_truman

print(f"Predicted: {pred_truman:.1f}%")
print(f"Actual:    {actual_truman:.1f}%")
print(f"Residual:  {residual:+.1f} percentage points")
# Out:
# Predicted: 72.3%
# Actual:    76.0%
# Residual:  +3.7 percentage points

# %% [markdown]
# ## 4. ANCOVA-Style Interaction Model

# %%
m = smf.ols("graduation_rate ~ sat_total * sector", data=df).fit()
m.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        graduation_rate   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.579
# Method:                 Least Squares   F-statistic:                     22.05
# Date:                Sat, 11 Apr 2026   Prob (F-statistic):           8.44e-09
# Time:                        20:44:41   Log-Likelihood:                -186.28
# No. Observations:                  47   AIC:                             380.6
# Df Residuals:                      43   BIC:                             388.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## 5. Interactive Plot (Plotly)
#
# Hover over each point to see the school name, SAT score, and graduation rate.

# %%
colors = {'Public': '#3B82F6', 'Private': '#F97316'}
fig = go.Figure()

for sector in ['Public', 'Private']:
    sub = df[df['sector'] == sector]
    slope = pub_slope if sector == 'Public' else pri_slope
    intercept = pub_int if sector == 'Public' else pri_int

    # Scatter points
    # Use 'school' column if it exists, otherwise fall back to index
    label_col = 'school' if 'school' in df.columns else df.index.astype(str)
    hover_labels = sub[label_col] if 'school' in df.columns else sub.index.astype(str)

    fig.add_trace(go.Scatter(
        x=sub['sat_total'],
        y=sub['graduation_rate'],
        mode='markers',
        name=sector,
        marker=dict(color=colors[sector], size=9, opacity=0.85,
                    line=dict(width=1, color='white')),
        customdata=hover_labels,
        hovertemplate=(
            "<b>%{customdata}</b><br>"
            "SAT: %{x}<br>"
            "Grad rate: %{y:.1f}%"
            "<extra></extra>"
        )
    ))

    # Regression line
    x_range = np.linspace(sub['sat_total'].min(), sub['sat_total'].max(), 100)
    y_range = intercept + slope * x_range
    fig.add_trace(go.Scatter(
        x=x_range, y=y_range,
        mode='lines',
        name=f'{sector} fit',
        line=dict(color=colors[sector], width=2, dash='solid'),
        showlegend=False,
        hoverinfo='skip'
    ))

# Truman State annotation
fig.add_trace(go.Scatter(
    x=[sat_truman], y=[actual_truman],
    mode='markers+text',
    marker=dict(color='#EF4444', size=14, symbol='star',
                line=dict(width=1.5, color='white')),
    text=['Truman State'],
    textposition='top right',
    name='Truman State',
    hovertemplate=(
        "<b>Truman State University</b><br>"
        "SAT: %{x}<br>"
        "Actual grad rate: %{y:.1f}%<br>"
        f"Predicted: {pred_truman:.1f}%"
        "<extra></extra>"
    )
))

fig.update_layout(
    title='Graduation Rate vs SAT Score by Sector',
    xaxis_title='SAT Total (Math + Verbal)',
    yaxis_title='Graduation Rate (%)',
    legend=dict(x=0.01, y=0.99),
    template='plotly_white',
    width=750, height=500
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 6. Regression Diagnostics
#
# Using the combined ANCOVA model to check OLS assumptions:
# 1. **Residuals vs Fitted** — checks linearity and homoscedasticity
# 2. **Q-Q Plot** — checks normality of residuals
# 3. **Cook's Distance** — identifies influential observations

# %%
influence = OLSInfluence(m)
fitted    = m.fittedvalues
residuals = m.resid
std_resid = influence.resid_studentized_internal
cooks_d   = influence.cooks_distance[0]

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# --- Plot 1: Residuals vs Fitted ---
ax = axes[0]
ax.scatter(fitted, residuals, alpha=0.7, edgecolors='white', linewidth=0.5,
           c='#3B82F6')
ax.axhline(0, color='#EF4444', linestyle='--', linewidth=1)
ax.set_xlabel('Fitted values')
ax.set_ylabel('Residuals')
ax.set_title('Residuals vs Fitted')

# Flag points with large residuals
threshold = 2 * residuals.std()
for i, (x, y) in enumerate(zip(fitted, residuals)):
    if abs(y) > threshold:
        ax.annotate(str(i), (x, y), textcoords='offset points',
                    xytext=(5, 5), fontsize=8, color='#EF4444')

# --- Plot 2: Q-Q Plot ---
ax = axes[1]
sm.qqplot(residuals, line='s', ax=ax, alpha=0.7,
          markerfacecolor='#3B82F6', markeredgecolor='white')
ax.set_title('Normal Q-Q Plot')
ax.get_lines()[1].set_color('#EF4444')  # reference line

# --- Plot 3: Cook's Distance ---
ax = axes[2]
n = len(df)
ax.bar(range(n), cooks_d, color='#3B82F6', alpha=0.7)
cutoff = 4 / n
ax.axhline(cutoff, color='#EF4444', linestyle='--', linewidth=1,
           label=f"Cutoff (4/n = {cutoff:.3f})")
ax.set_xlabel('Observation index')
ax.set_ylabel("Cook's distance")
ax.set_title("Cook's Distance")
ax.legend(fontsize=8)

# Annotate influential points
for i, cd in enumerate(cooks_d):
    if cd > cutoff:
        ax.annotate(str(i), (i, cd), textcoords='offset points',
                    xytext=(0, 4), fontsize=8, color='#EF4444', ha='center')

plt.suptitle('Regression Diagnostics — ANCOVA Model', fontsize=13, y=1.02)
plt.tight_layout()
# Fixed: Saving to current directory instead of ../figures/
plt.savefig('diagnostics.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"\nInfluential observations (Cook's D > {cutoff:.3f}):")
for i, cd in enumerate(cooks_d):
    if cd > cutoff:
        row = df.iloc[i]
        print(f"  Index {i}: sector={row['sector']}, sat={row['sat_total']}, "
              f"grad_rate={row['graduation_rate']:.1f}%, Cook's D={cd:.3f}")
# Out:
# Influential observations (Cook's D > 0.085):
#   Index 2: sector=Public, sat=1240.0, grad_rate=93.0%, Cook's D=0.228
#   Index 11: sector=Public, sat=1211.0, grad_rate=95.0%, Cook's D=0.285
#   Index 12: sector=Public, sat=1202.0, grad_rate=49.0%, Cook's D=0.371
#   Index 18: sector=Public, sat=785.0, grad_rate=47.0%, Cook's D=0.096
#   Index 23: sector=Private, sat=1410.0, grad_rate=83.0%, Cook's D=0.128

# %% [markdown]
# ## 7. Sensitivity Check — Imputed SAT Values
#
# Some SAT scores were imputed from ACT (flagged by `sat_imputed = 1`).
# This cell re-runs the public regression after removing imputed values to check stability.

# %%
pub_clean = pub[pub['sat_imputed'] == 0]

if len(pub_clean) < 3:
    print("Not enough non-imputed public observations to refit.")
else:
    slope_c, int_c, r_c, p_c, _ = linreg(pub_clean)
    print("Public regression — FULL sample:")
    print(f"  grad_rate = {pub_int:.3f} + {pub_slope:.6f} * sat_total  (r={pub_r:.3f})")
    print()
    print(f"Public regression — non-imputed only (n={len(pub_clean)}):")
    print(f"  grad_rate = {int_c:.3f} + {slope_c:.6f} * sat_total  (r={r_c:.3f})")
    print()

    pred_full  = pub_int  + pub_slope  * sat_truman
    pred_clean = int_c + slope_c * sat_truman
    print(f"Truman prediction (SAT=1190):")
    print(f"  Full sample:      {pred_full:.1f}%")
    print(f"  Non-imputed only: {pred_clean:.1f}%")
    print(f"  Difference:       {abs(pred_full - pred_clean):.1f} pp")
# Out:
# Public regression — FULL sample:
#   grad_rate = -51.385 + 0.103957 * sat_total  (r=0.701)
#
# Public regression — non-imputed only (n=13):
#   grad_rate = -54.531 + 0.108249 * sat_total  (r=0.719)
#
# Truman prediction (SAT=1190):
#   Full sample:      72.3%
#   Non-imputed only: 74.3%
#   Difference:       2.0 pp

# %% [markdown]
# ## 8. Prediction Function

# %%
def predict_grad_rate(sat_score: int, sector: str) -> dict:
    """
    Predict graduation rate given SAT score and sector.

    Parameters
    ----------
    sat_score : int
        Combined SAT Math + Verbal score.
    sector : str
        'Public' or 'Private'.

    Returns
    -------
    dict with predicted rate, equation used, and a caution if out of range.
    """
    if sector == 'Public':
        pred = pub_int + pub_slope * sat_score
        sat_range = (pub['sat_total'].min(), pub['sat_total'].max())
    elif sector == 'Private':
        pred = pri_int + pri_slope * sat_score
        sat_range = (pri['sat_total'].min(), pri['sat_total'].max())
    else:
        raise ValueError("sector must be 'Public' or 'Private'")

    out_of_range = not (sat_range[0] <= sat_score <= sat_range[1])

    return {
        'sector': sector,
        'sat_score': sat_score,
        'predicted_grad_rate': round(pred, 1),
        'training_sat_range': sat_range,
        'extrapolation_warning': out_of_range
    }

# Examples
print(predict_grad_rate(1190, 'Public'))   # Truman State
print(predict_grad_rate(1350, 'Private'))
print(predict_grad_rate(900,  'Public'))   # will trigger extrapolation warning
# Out:
# {'sector': 'Public', 'sat_score': 1190, 'predicted_grad_rate': np.float64(72.3), 'training_sat_range': (785.0, 1240.0), 'extrapolation_warning': False}
# {'sector': 'Private', 'sat_score': 1350, 'predicted_grad_rate': np.float64(92.2), 'training_sat_range': (780.0, 1410.0), 'extrapolation_warning': False}
# {'sector': 'Public', 'sat_score': 900, 'predicted_grad_rate': np.float64(42.2), 'training_sat_range': (785.0, 1240.0), 'extrapolation_warning': False}
