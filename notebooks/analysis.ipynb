# %% [markdown]
# # Graduation Rates vs SAT (Public vs Private)
#
# This notebook reproduces the core analysis:
# - Scatter plots of graduation rate vs SAT
# - Correlations by sector
# - Separate least-squares regressions (public vs private)
# - Prediction for Truman at SAT ≈ 1190
# - (Bonus) Single model with an interaction term (ANCOVA-style)
#
# Dataset: `data/GradRates.xlsx` (cleaned version: `data/grad_rates_clean.csv`)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf

df = pd.read_csv("../data/grad_rates_clean.csv")
df.head(), df.shape

# %%
df['sector'].value_counts()

# %%
# Scatter plot by sector (default colors)
plt.figure()
for sector, marker in [('Public','o'),('Private','x')]:
    sub = df[df['sector']==sector]
    plt.scatter(sub['sat_total'], sub['graduation_rate'], marker=marker, label=sector)
plt.xlabel("SAT (Math + Verbal)")
plt.ylabel("Graduation rate (%)")
plt.title("Graduation Rate vs SAT")
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Correlations
def corr(sub):
    return np.corrcoef(sub['sat_total'], sub['graduation_rate'])[0,1]

corr_public = corr(df[df['sector']=='Public'])
corr_private = corr(df[df['sector']=='Private'])
corr_public, corr_private

# %%
# Separate regressions (SciPy)
def linreg(sub):
    x = sub['sat_total'].astype(float)
    y = sub['graduation_rate'].astype(float)
    slope, intercept, r, p, se = stats.linregress(x, y)
    return slope, intercept, r, p, se

pub = df[df['sector']=='Public']
pri = df[df['sector']=='Private']

pub_slope, pub_int, pub_r, pub_p, pub_se = linreg(pub)
pri_slope, pri_int, pri_r, pri_p, pri_se = linreg(pri)

(pub_int, pub_slope, pub_r, pub_p), (pri_int, pri_slope, pri_r, pri_p)

# %%
# Truman prediction (SAT ≈ 1190)
sat_truman = 1190
pred_truman = pub_int + pub_slope * sat_truman
pred_truman

# %%
# Bonus: single model with interaction (ANCOVA-style)
m = smf.ols("graduation_rate ~ sat_total * sector", data=df).fit()
m.summary()

# %% [markdown]
# ## Diagnostic Plots
#
# Regression diagnostics to verify model assumptions:
# 1. **Residuals vs Fitted** — check linearity and homoscedasticity
# 2. **Q-Q Plot** — check normality of residuals
# 3. **Scale-Location** — check for heteroscedasticity

# %%
from scipy.stats import probplot

def diagnostic_plots(sub, slope, intercept, label, color):
    """Plot residuals vs fitted, Q-Q, and scale-location for a regression."""
    x = sub['sat_total'].astype(float).values
    y = sub['graduation_rate'].astype(float).values
    fitted = intercept + slope * x
    residuals = y - fitted
    sqrt_abs_res = np.sqrt(np.abs(residuals))

    fig, axes = plt.subplots(1, 3, figsize=(15, 4))
    fig.suptitle(f"Regression Diagnostics — {label}", fontsize=13)

    # 1. Residuals vs Fitted
    axes[0].scatter(fitted, residuals, color=color, alpha=0.7, edgecolors='k', linewidths=0.5)
    axes[0].axhline(0, color='red', linestyle='--', linewidth=1)
    axes[0].set_xlabel("Fitted values")
    axes[0].set_ylabel("Residuals")
    axes[0].set_title("Residuals vs Fitted")

    # 2. Q-Q Plot
    (osm, osr), (slope_qq, intercept_qq, r_qq) = probplot(residuals, dist="norm")
    axes[1].scatter(osm, osr, color=color, alpha=0.7, edgecolors='k', linewidths=0.5)
    axes[1].plot(osm, slope_qq * np.array(osm) + intercept_qq, color='red', linestyle='--', linewidth=1)
    axes[1].set_xlabel("Theoretical quantiles")
    axes[1].set_ylabel("Sample quantiles")
    axes[1].set_title("Normal Q-Q Plot")

    # 3. Scale-Location
    axes[2].scatter(fitted, sqrt_abs_res, color=color, alpha=0.7, edgecolors='k', linewidths=0.5)
    axes[2].set_xlabel("Fitted values")
    axes[2].set_ylabel("√|Residuals|")
    axes[2].set_title("Scale-Location")

    plt.tight_layout()
    plt.show()

    # Shapiro-Wilk normality test
    from scipy.stats import shapiro
    stat, p_val = shapiro(residuals)
    print(f"{label} — Shapiro-Wilk: W={stat:.4f}, p={p_val:.4f} "
          f"({'normality OK' if p_val > 0.05 else 'non-normal residuals'})")

diagnostic_plots(pub, pub_slope, pub_int, "Public", color="#1f77b4")
diagnostic_plots(pri, pri_slope, pri_int, "Private", color="#ff7f0e")
